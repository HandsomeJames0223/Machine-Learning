# %% [markdown]
# <a href="https://colab.research.google.com/github/HandsomeJames0223/Machine-Learning/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #scikit-learn

# %% [markdown]
# #https://pandas.pydata.org/docs/user_guide/io.html
# #pandas 資訊
#
# #https://github.com/modin-project/modin
# #若資料量太大，pandas不能用，可以用modin

# %%
import pandas as pd
from sklearn.datasets import load_boston
pd.options.display.max_rows = 200
boston = load_boston()
df = pd.DataFrame(boston["data"], columns = boston["feature_names"])
df["target"] = boston["target"]
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...     ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67    22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08    20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64    23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48    22.0
# ...

# %%
# 預處理: pandas/DataFrame
# 機器學習: numpy/np.array
# 以後x是input，y是output
import numpy as np
from sklearn.model_selection import train_test_split
x, y = df.drop(["target"], axis = 1), df["target"]
x, y = np.array(x), np.array(y)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)

# %%
from sklearn.tree import DecisionTreeRegressor
# 創造方法
reg = DecisionTreeRegressor(max_depth = 6, random_state=0)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=6,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
import graphviz
from sklearn.tree import export_graphviz
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.export_graphviz.html
# graphviz具有可解釋性
g = export_graphviz(reg, feature_names = boston["feature_names"], filled = True)
graphviz.Source(g)

# %%
from sklearn.metrics import r2_score
pre = reg.predict(x_test)
r2_score(y_test, pre)
# Out:
# 0.2351911891152323
